# %% [markdown]
# # Analysis with astropy

# %%
# %matplotlib widget

# %% [markdown]
# Import the necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

from astropy.io import fits 
from spectral_cube import SpectralCube
from astropy.visualization import make_lupton_rgb, ManualInterval, make_rgb, LogStretch
from astropy.modeling import models, fitting
import astropy.units as u
from astropy.wcs.utils import pixel_to_skycoord, proj_plane_pixel_scales

from mpdaf.obj import Cube, WCS, WaveCoord

# %% [markdown]
# Open the FITS file and check whats inside

# %%
file = fits.open('/home/polaris/nitrogen_mrk996/data/Mrk996.fits')
file.info()
# Out:
# Filename: /home/polaris/nitrogen_mrk996/data/Mrk996.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    1811   ()
#   1  DATA          1 ImageHDU        44   (358, 357, 3681)   float32
#   2  STAT          1 ImageHDU        44   (358, 357, 3681)   float32

# %% [markdown]
# The PRIMARY is empty.
# The DATA has the spectra.
# The STAT has the variances.

# %%
data_file = file[1]
stats_file = file[2]

file[1].header
# Out:
# XTENSION= 'IMAGE   '           / IMAGE extension
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    3 / number of data axes
# NAXIS1  =                  358 / length of data axis 1
# NAXIS2  =                  357 / length of data axis 2
# NAXIS3  =                 3681 / length of data axis 3
# PCOUNT  =                    0 / required keyword; must = 0
# GCOUNT  =                    1 / required keyword; must = 1
# OBJECT  = 'Mrk996 (DATA)'
# CRPIX1  =      157.48722028022 / Pixel coordinate of reference point
# CRPIX2  =     191.081028855458 / Pixel coordinate of reference point
# CD1_1   = -6.99722222222222E-06 / Coordinate transformation matrix element
# CD1_2   =                   0. / Coordinate transformation matrix element
# CD2_1   =                   0. / Coordinate transformation matrix element
# CD2_2   = 7.06111111111111E-06 / Coordinate transformation matrix element
# CUNIT1  = 'deg     '           / Units of coordinate increment and value
# CUNIT2  = 'deg     '           / Units of coordinate increment and value
# CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
# CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
# CSYER1  =    3.14895034769E-06 / [deg] Systematic error in coordinate
# CSYER2  =    3.60842227799E-06 / [deg] Systematic error in coordinate
# CRVAL1  =            21.898629
# CRVAL2  =             -6.32646
# CTYPE3  = 'AWAV    '
# CUNIT3  = 'angstrom'
# CD3_3   =                 1.25
# CRPIX3  =                   1.
# CRVAL3  =     4749.61865234375
# CRDER3  =                0.026 / [angstrom] Random error in spectral coordinate
# CD1_3   =                   0.
# CD2_3   =                   0.
# CD3_1   =                   0.
# CD3_2   =                   0.
# EXTNAME = 'DATA    '           / This extension contains data values
# HDUCLASS= 'ESO     '           / class name (ESO format)
# HDUDOC  = 'SDP     '           / document with class description
# HDUVERS = 'SDP version 8'
# HDUCLAS1= 'IMAGE   '           / Image data format
# HDUCLAS2= 'DATA    '           / this extension contains the data itself
# ERRDATA = 'STAT    '           / pointer to the variance extension
# BUNIT   = '10**(-20)erg.s**(-1).cm**(-2).angstrom**(-1)'
# TITLE   = 'Mrk996_4003485_2024-12-04T02:22:05.486_NFM-AO-N_OBJ'
# CHECKSUM= '8ROgAPLg2PLg8PLg'   / HDU checksum updated 2024-12-28T00:48:54
# DATASUM = '1927436410'         / data unit checksum updated 2024-12-28T00:48:54

# %% [markdown]
# Define a Spectral Cube in the DATA

# %%
cube = SpectralCube.read(data_file)
file.close()
print(cube)
# Out:
# SpectralCube with shape=(3681, 357, 358) and unit=1e-20 erg / (Angstrom s cm2):
#  n_x:    358  type_x: RA---TAN  unit_x: deg    range:    21.897217 deg:   21.899731 deg
#  n_y:    357  type_y: DEC--TAN  unit_y: deg    range:    -6.327802 deg:   -6.325288 deg
#  n_s:   3681  type_s: AWAV      unit_s: Angstrom  range:     4749.619 Angstrom:    9349.619 Angstrom

# %%
cube.shape[0]
# Out:
# 3681

# %%
coordinates = pixel_to_skycoord(177, 197, wcs=cube.wcs)

ositions = SkyCoord(ra=21.89848459 * u.deg, dec=-6.32641114 * u.deg, frame='icrs')
print(coordinates)
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (21.89848459, -6.32641114)>

# %%
spectral_axis = cube.spectral_axis
wavelengths = np.linspace(spectral_axis[0], spectral_axis[-1], 4)

channel = np.argmin(np.abs(cube.spectral_axis - 6275 * u.angstrom))

print(channel)
print(wavelengths)



#########################################################
center_pos = (177, 197)  # pixels
radius_arcsec = 0.15  # arcseconds

spatial_pixel_scale = 0.025 # arcseconds/pixel
radius_pixels = radius_arcsec / spatial_pixel_scale

# Define the circular aperture
yy, xx = np.indices(cube.shape[1:])

aperture_mask = (
    (xx - center_pos[0])**2 +
    (yy - center_pos[1])**2
) <= radius_pixels**2

continuum_image =  cube[channel].value
continuum_flux = np.nansum(continuum_image[aperture_mask])

print(continuum_flux)

#######################33
print(cube.unit)
# Out:
# 1220
# [4749.61865234 6282.95198568 7816.28531901 9349.61865234] Angstrom
# 7017.635
# 1e-20 erg / (Angstrom s cm2)
# WARNING: WCSWarning: WCS1 is missing card CSYER1 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card CSYER2 [spectral_cube.wcs_utils]

# %% [markdown]
# ## Create an RGB image of the cube

# %% [markdown]
# Define some aproximate wavelenght range for colors

# %%
blue = [450 * u.nm, 500 * u.nm]
green = [500 * u.nm, 565 * u.nm]
red = [625 * u.nm, 626 * u.nm]

# %%
test = cube.wcs.spectral
print(test)
print(type(test))

cdelt = cube.wcs.spectral.wcs.crval[0]
print(cdelt)
# Out:
# WCS Keywords
#
# Number of WCS axes: 1
# CTYPE : 'AWAV'
# CUNIT : 'm'
# CRVAL : 4.74961865234375e-07
# CRPIX : 1.0
# PC1_1  : 1.0
# CDELT : 1.25e-10
# NAXIS : 3681
# <class 'astropy.wcs.wcs.WCS'>
# 4.74961865234375e-07

# %% [markdown]
# A spectral slab is a subsection of the cube for a given range.

# %%
blue_cube = cube.spectral_slab(*blue)
green_cube = cube.spectral_slab(*green)

red_cube = cube.spectral_slab(*red)
red_moment0 = red_cube.moment(order=0)
red_moment0.quicklook()

# %%
plt.imshow(red_moment0, origin='lower')
plt.colorbar()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
blue_moment_0 = blue_cube.moment(order=0)
green_moment_0 = green_cube.moment(order=0)
red_moment_0 = red_cube.moment(order=0)

# %% [markdown]
# Create a function that give me coordinates when clicking in the image

# %%
def onclick(event):

    # Only respond to clicks inside the image
    if event.inaxes != ax:
        return

    # Pixel coordinates
    x_pixel = event.xdata
    y_pixel = event.ydata

    # Convert pixel -> world coordinates
    skycoord = blue_moment_0.wcs.pixel_to_world(
        x_pixel,
        y_pixel
    )

    print("\n-----------------------------")
    print(f"Pixel coordinates:")
    print(f"    X = {x_pixel:.2f}")
    print(f"    Y = {y_pixel:.2f}")

    print("\nWorld coordinates:")
    print(f"    RA  = {skycoord.ra.to_string(unit=u.hourangle, sep=':')}")
    print(f"    DEC = {skycoord.dec.to_string(unit=u.deg, sep=':')}")
    print("-----------------------------")

    # Display the coordinates on the image
    ax.plot(
        x_pixel,
        y_pixel,
        marker="+",
        markersize=12,
        markeredgewidth=2
    )

    ax.annotate(
        f"({x_pixel:.1f}, {y_pixel:.1f})\n"
        f"{skycoord.ra.to_string(unit=u.hourangle, sep=':')}\n"
        f"{skycoord.dec.to_string(unit=u.deg, sep=':')}",
        xy=(x_pixel, y_pixel),
        xytext=(10, 10),
        textcoords="offset points",
        fontsize=9,
        bbox=dict(
            boxstyle="round",
            facecolor="white",
            alpha=0.8
        )
    )

    fig.canvas.draw_idle()

# %%
# rgb_image = make_rgb(blue_moment_0, green_moment_0, red_moment_0,stretch=LogStretch(a=10), filename="mrk996_rgb.jpeg")

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection=red_cube.wcs)

im = ax.imshow(red_cube)

# Add axes labels
ax.set_xlabel("RA", fontsize=12)
ax.set_ylabel("DEC", fontsize=12)

# Add the clicky functionality
#fig.canvas.mpl_connect("button_press_event", onclick)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:992, in Quantity.to_value(self, unit, equivalencies)
#     991 try:
# --> 992     scale = self.unit._to(unit)
#     993 except Exception:
#     994     # Short-cut failed; try default (maybe equivalencies help).
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:623, in UnitBase._to(self, other)
#     621         return self_decomposed.scale / other_decomposed.scale
# --> 623 raise UnitConversionError(f"'{self!r}' is not a scaled version of '{other!r}'")
#
# UnitConversionError: 'Unit("1e-20 erg / (Angstrom s cm2)")' is not a scaled version of 'Unit(dimensionless)'
#
# During handling of the above exception, another exception occurred:
#
# UnitConversionError                       Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:1346, in Quantity.__float__(self)
#    1345 try:
# -> 1346     return float(self.to_value(dimensionless_unscaled))
#    1347 except (UnitsError, TypeError):
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:995, in Quantity.to_value(self, unit, equivalencies)
#     993 except Exception:
#     994     # Short-cut failed; try default (maybe equivalencies help).
# --> 995     value = self._to_value(unit, equivalencies)
#     996 else:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:901, in Quantity._to_value(self, unit, equivalencies)
#     899 if not self.dtype.names or isinstance(self.unit, StructuredUnit):
#     900     # Standard path, let unit to do work.
# --> 901     return self.unit.to(
#     902         unit, self.view(np.ndarray), equivalencies=equivalencies
#     903     )
#     905 else:
#     906     # The .to() method of a simple unit cannot convert a structured
#     907     # dtype, so we work around it, by recursing.
#     908     # TODO: deprecate this?
#     909     # Convert simple to Structured on initialization?
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:659, in UnitBase.to(self, other, value, equivalencies)
#     658 else:
# --> 659     return self.get_converter(Unit(other), equivalencies)(value)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:588, in UnitBase.get_converter(self, other, equivalencies)
#     586                 return lambda v: b(converter(v))
# --> 588 raise exc
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:571, in UnitBase.get_converter(self, other, equivalencies)
#     570 try:
# --> 571     return self._apply_equivalencies(
#     572         self, other, self._normalize_equivalencies(equivalencies)
#     573     )
#     574 except UnitsError as exc:
#     575     # Last hope: maybe other knows how to do it?
#     576     # We assume the equivalencies have the unit itself as first item.
#     577     # TODO: maybe better for other to have a `_back_converter` method?
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:522, in UnitBase._apply_equivalencies(self, unit, other, equivalencies)
#     520 other_str = get_err_str(other)
# --> 522 raise UnitConversionError(f"{unit_str} and {other_str} are not convertible")
#
# UnitConversionError: '1e-20 erg / (Angstrom s cm2)' (power density/spectral flux density wav) and '' (dimensionless) are not convertible
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/ipywidgets/widgets/widget.py:191, in CallbackDispatcher.__call__(self, *args, **kwargs)
#     189 for callback in self.callbacks:
#     190     try:
# --> 191         local_value = callback(*args, **kwargs)
#     192     except Exception as e:
#     193         ip = get_ipython()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/ipympl/backend_nbagg.py:289, in Canvas._handle_message(self, object, content, buffers)
#     286     self.manager.handle_json(content)
#     288 else:
# --> 289     self.manager.handle_json(content)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:502, in FigureManagerWebAgg.handle_json(self, content)
#     501 def handle_json(self, content):
# --> 502     self.canvas.handle_event(content)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:289, in FigureCanvasWebAggCore.handle_event(self, event)
#     286 e_type = event['type']
#     287 handler = getattr(self, f'handle_{e_type}',
#     288                   self.handle_unknown_event)
# --> 289 return handler(event)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:304, in FigureCanvasWebAggCore.handle_draw(self, event)
#     303 def handle_draw(self, event):
# --> 304     self.draw()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:192, in FigureCanvasWebAggCore.draw(self)
#     190 self._png_is_old = True
#     191 try:
# --> 192     super().draw()
#     193 finally:
#     194     self.manager.refresh_all()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_agg.py:438, in FigureCanvasAgg.draw(self)
#     435 # Acquire a lock on the shared font cache.
#     436 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     437       else nullcontext()):
# --> 438     self.figure.draw(self.renderer)
#     439     # A GUI class may be need to update a window using this draw, so
#     440     # don't forget to call the superclass.
#     441     super().draw()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/figure.py:3282, in Figure.draw(self, renderer)
#    3279             # ValueError can occur when resizing a window.
#    3281     self.patch.draw(renderer)
# -> 3282     mimage._draw_list_compositing_images(
#    3283         renderer, self, artists, self.suppressComposite)
#    3285     renderer.close_group('figure')
#    3286 finally:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:38, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     renderer.stop_rasterizing()
#      36     renderer._rasterizing = False
# ---> 38 return draw(artist, renderer, *args, **kwargs)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/visualization/wcsaxes/core.py:591, in WCSAxes.draw(self, renderer)
#     588 # We need to make sure that that frame path is up to date
#     589 self.coords.frame._update_patch_path()
# --> 591 super().draw(renderer)
#     593 self._drawn = True
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/axes/_base.py:3367, in _AxesBase.draw(self, renderer)
#    3364 if artists_rasterized:
#    3365     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3367 mimage._draw_list_compositing_images(
#    3368     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3370 renderer.close_group('axes')
#    3371 self.stale = False
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/image.py:633, in _ImageBase.draw(self, renderer)
#     631         renderer.draw_image(gc, l, b, im, trans)
#     632 else:
# --> 633     im, l, b, trans = self.make_image(
#     634         renderer, renderer.get_image_magnification())
#     635     if im is not None:
#     636         renderer.draw_image(gc, l, b, im)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/image.py:936, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     933 transformed_bbox = TransformedBbox(bbox, trans)
#     934 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     935         else self.get_figure(root=True).bbox)
# --> 936 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     937                         magnification, unsampled=unsampled)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/image.py:516, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     514 if A.ndim == 2:  # interpolation_stage = 'rgba'
#     515     self.norm.autoscale_None(A)
# --> 516     A = self.to_rgba(A)
#     517 if A.dtype == np.uint8:
#     518     # uint8 is too imprecise for premultiplied alpha roundtrips.
#     519     A = np.divide(A, 0xff, dtype=np.float32)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colorizer.py:358, in _ColorizerInterface.to_rgba(self, x, alpha, bytes, norm)
#     328 def to_rgba(self, x, alpha=None, bytes=False, norm=True):
#     329     """
#     330     Return a normalized RGBA array corresponding to *x*.
#     331
#    (...)    356
#     357     """
# --> 358     return self._colorizer.to_rgba(x, alpha=alpha, bytes=bytes, norm=norm)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colorizer.py:145, in Colorizer.to_rgba(self, x, alpha, bytes, norm)
#     143 x = ma.asarray(x)
#     144 if norm:
# --> 145     x = self.norm(x)
#     146 rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     147 return rgba
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colors.py:2546, in Normalize.__call__(self, value, clip)
#    2544     self.autoscale_None(result)
#    2545 # Convert at least to float, without losing precision.
# -> 2546 (vmin,), _ = self.process_value(self.vmin)
#    2547 (vmax,), _ = self.process_value(self.vmax)
#    2548 if vmin == vmax:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colors.py:2525, in Normalize.process_value(value)
#    2523 if is_scalar:
#    2524     value = [value]
# -> 2525 dtype = np.min_scalar_type(value)
#    2526 if np.issubdtype(dtype, np.integer) or dtype.type is np.bool_:
#    2527     # bool_/int8/int16 -> float32; int32/int64 -> float64
#    2528     dtype = np.promote_types(dtype, np.float32)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:1348, in Quantity.__float__(self)
#    1346     return float(self.to_value(dimensionless_unscaled))
#    1347 except (UnitsError, TypeError):
# -> 1348     raise TypeError(
#    1349         "only dimensionless scalar quantities can be "
#    1350         "converted to Python scalars"
#    1351     )
#
# TypeError: only dimensionless scalar quantities can be converted to Python scalars
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:992, in Quantity.to_value(self, unit, equivalencies)
#     991 try:
# --> 992     scale = self.unit._to(unit)
#     993 except Exception:
#     994     # Short-cut failed; try default (maybe equivalencies help).
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:623, in UnitBase._to(self, other)
#     621         return self_decomposed.scale / other_decomposed.scale
# --> 623 raise UnitConversionError(f"'{self!r}' is not a scaled version of '{other!r}'")
#
# UnitConversionError: 'Unit("1e-20 erg / (Angstrom s cm2)")' is not a scaled version of 'Unit(dimensionless)'
#
# During handling of the above exception, another exception occurred:
#
# UnitConversionError                       Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:1346, in Quantity.__float__(self)
#    1345 try:
# -> 1346     return float(self.to_value(dimensionless_unscaled))
#    1347 except (UnitsError, TypeError):
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:995, in Quantity.to_value(self, unit, equivalencies)
#     993 except Exception:
#     994     # Short-cut failed; try default (maybe equivalencies help).
# --> 995     value = self._to_value(unit, equivalencies)
#     996 else:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:901, in Quantity._to_value(self, unit, equivalencies)
#     899 if not self.dtype.names or isinstance(self.unit, StructuredUnit):
#     900     # Standard path, let unit to do work.
# --> 901     return self.unit.to(
#     902         unit, self.view(np.ndarray), equivalencies=equivalencies
#     903     )
#     905 else:
#     906     # The .to() method of a simple unit cannot convert a structured
#     907     # dtype, so we work around it, by recursing.
#     908     # TODO: deprecate this?
#     909     # Convert simple to Structured on initialization?
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:659, in UnitBase.to(self, other, value, equivalencies)
#     658 else:
# --> 659     return self.get_converter(Unit(other), equivalencies)(value)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:588, in UnitBase.get_converter(self, other, equivalencies)
#     586                 return lambda v: b(converter(v))
# --> 588 raise exc
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:571, in UnitBase.get_converter(self, other, equivalencies)
#     570 try:
# --> 571     return self._apply_equivalencies(
#     572         self, other, self._normalize_equivalencies(equivalencies)
#     573     )
#     574 except UnitsError as exc:
#     575     # Last hope: maybe other knows how to do it?
#     576     # We assume the equivalencies have the unit itself as first item.
#     577     # TODO: maybe better for other to have a `_back_converter` method?
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:522, in UnitBase._apply_equivalencies(self, unit, other, equivalencies)
#     520 other_str = get_err_str(other)
# --> 522 raise UnitConversionError(f"{unit_str} and {other_str} are not convertible")
#
# UnitConversionError: '1e-20 erg / (Angstrom s cm2)' (power density/spectral flux density wav) and '' (dimensionless) are not convertible
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/ipywidgets/widgets/widget.py:191, in CallbackDispatcher.__call__(self, *args, **kwargs)
#     189 for callback in self.callbacks:
#     190     try:
# --> 191         local_value = callback(*args, **kwargs)
#     192     except Exception as e:
#     193         ip = get_ipython()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/ipympl/backend_nbagg.py:289, in Canvas._handle_message(self, object, content, buffers)
#     286     self.manager.handle_json(content)
#     288 else:
# --> 289     self.manager.handle_json(content)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:502, in FigureManagerWebAgg.handle_json(self, content)
#     501 def handle_json(self, content):
# --> 502     self.canvas.handle_event(content)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:289, in FigureCanvasWebAggCore.handle_event(self, event)
#     286 e_type = event['type']
#     287 handler = getattr(self, f'handle_{e_type}',
#     288                   self.handle_unknown_event)
# --> 289 return handler(event)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:304, in FigureCanvasWebAggCore.handle_draw(self, event)
#     303 def handle_draw(self, event):
# --> 304     self.draw()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:192, in FigureCanvasWebAggCore.draw(self)
#     190 self._png_is_old = True
#     191 try:
# --> 192     super().draw()
#     193 finally:
#     194     self.manager.refresh_all()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_agg.py:438, in FigureCanvasAgg.draw(self)
#     435 # Acquire a lock on the shared font cache.
#     436 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     437       else nullcontext()):
# --> 438     self.figure.draw(self.renderer)
#     439     # A GUI class may be need to update a window using this draw, so
#     440     # don't forget to call the superclass.
#     441     super().draw()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/figure.py:3282, in Figure.draw(self, renderer)
#    3279             # ValueError can occur when resizing a window.
#    3281     self.patch.draw(renderer)
# -> 3282     mimage._draw_list_compositing_images(
#    3283         renderer, self, artists, self.suppressComposite)
#    3285     renderer.close_group('figure')
#    3286 finally:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:38, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     renderer.stop_rasterizing()
#      36     renderer._rasterizing = False
# ---> 38 return draw(artist, renderer, *args, **kwargs)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/visualization/wcsaxes/core.py:591, in WCSAxes.draw(self, renderer)
#     588 # We need to make sure that that frame path is up to date
#     589 self.coords.frame._update_patch_path()
# --> 591 super().draw(renderer)
#     593 self._drawn = True
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/axes/_base.py:3367, in _AxesBase.draw(self, renderer)
#    3364 if artists_rasterized:
#    3365     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3367 mimage._draw_list_compositing_images(
#    3368     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3370 renderer.close_group('axes')
#    3371 self.stale = False
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/image.py:633, in _ImageBase.draw(self, renderer)
#     631         renderer.draw_image(gc, l, b, im, trans)
#     632 else:
# --> 633     im, l, b, trans = self.make_image(
#     634         renderer, renderer.get_image_magnification())
#     635     if im is not None:
#     636         renderer.draw_image(gc, l, b, im)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/image.py:936, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     933 transformed_bbox = TransformedBbox(bbox, trans)
#     934 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     935         else self.get_figure(root=True).bbox)
# --> 936 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     937                         magnification, unsampled=unsampled)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/image.py:516, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     514 if A.ndim == 2:  # interpolation_stage = 'rgba'
#     515     self.norm.autoscale_None(A)
# --> 516     A = self.to_rgba(A)
#     517 if A.dtype == np.uint8:
#     518     # uint8 is too imprecise for premultiplied alpha roundtrips.
#     519     A = np.divide(A, 0xff, dtype=np.float32)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colorizer.py:358, in _ColorizerInterface.to_rgba(self, x, alpha, bytes, norm)
#     328 def to_rgba(self, x, alpha=None, bytes=False, norm=True):
#     329     """
#     330     Return a normalized RGBA array corresponding to *x*.
#     331
#    (...)    356
#     357     """
# --> 358     return self._colorizer.to_rgba(x, alpha=alpha, bytes=bytes, norm=norm)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colorizer.py:145, in Colorizer.to_rgba(self, x, alpha, bytes, norm)
#     143 x = ma.asarray(x)
#     144 if norm:
# --> 145     x = self.norm(x)
#     146 rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     147 return rgba
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colors.py:2546, in Normalize.__call__(self, value, clip)
#    2544     self.autoscale_None(result)
#    2545 # Convert at least to float, without losing precision.
# -> 2546 (vmin,), _ = self.process_value(self.vmin)
#    2547 (vmax,), _ = self.process_value(self.vmax)
#    2548 if vmin == vmax:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colors.py:2525, in Normalize.process_value(value)
#    2523 if is_scalar:
#    2524     value = [value]
# -> 2525 dtype = np.min_scalar_type(value)
#    2526 if np.issubdtype(dtype, np.integer) or dtype.type is np.bool_:
#    2527     # bool_/int8/int16 -> float32; int32/int64 -> float64
#    2528     dtype = np.promote_types(dtype, np.float32)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:1348, in Quantity.__float__(self)
#    1346     return float(self.to_value(dimensionless_unscaled))
#    1347 except (UnitsError, TypeError):
# -> 1348     raise TypeError(
#    1349         "only dimensionless scalar quantities can be "
#    1350         "converted to Python scalars"
#    1351     )
#
# TypeError: only dimensionless scalar quantities can be converted to Python scalars
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:992, in Quantity.to_value(self, unit, equivalencies)
#     991 try:
# --> 992     scale = self.unit._to(unit)
#     993 except Exception:
#     994     # Short-cut failed; try default (maybe equivalencies help).
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:623, in UnitBase._to(self, other)
#     621         return self_decomposed.scale / other_decomposed.scale
# --> 623 raise UnitConversionError(f"'{self!r}' is not a scaled version of '{other!r}'")
#
# UnitConversionError: 'Unit("1e-20 erg / (s cm2)")' is not a scaled version of 'Unit(dimensionless)'
#
# During handling of the above exception, another exception occurred:
#
# UnitConversionError                       Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:1346, in Quantity.__float__(self)
#    1345 try:
# -> 1346     return float(self.to_value(dimensionless_unscaled))
#    1347 except (UnitsError, TypeError):
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:995, in Quantity.to_value(self, unit, equivalencies)
#     993 except Exception:
#     994     # Short-cut failed; try default (maybe equivalencies help).
# --> 995     value = self._to_value(unit, equivalencies)
#     996 else:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:901, in Quantity._to_value(self, unit, equivalencies)
#     899 if not self.dtype.names or isinstance(self.unit, StructuredUnit):
#     900     # Standard path, let unit to do work.
# --> 901     return self.unit.to(
#     902         unit, self.view(np.ndarray), equivalencies=equivalencies
#     903     )
#     905 else:
#     906     # The .to() method of a simple unit cannot convert a structured
#     907     # dtype, so we work around it, by recursing.
#     908     # TODO: deprecate this?
#     909     # Convert simple to Structured on initialization?
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:659, in UnitBase.to(self, other, value, equivalencies)
#     658 else:
# --> 659     return self.get_converter(Unit(other), equivalencies)(value)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:588, in UnitBase.get_converter(self, other, equivalencies)
#     586                 return lambda v: b(converter(v))
# --> 588 raise exc
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:571, in UnitBase.get_converter(self, other, equivalencies)
#     570 try:
# --> 571     return self._apply_equivalencies(
#     572         self, other, self._normalize_equivalencies(equivalencies)
#     573     )
#     574 except UnitsError as exc:
#     575     # Last hope: maybe other knows how to do it?
#     576     # We assume the equivalencies have the unit itself as first item.
#     577     # TODO: maybe better for other to have a `_back_converter` method?
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:522, in UnitBase._apply_equivalencies(self, unit, other, equivalencies)
#     520 other_str = get_err_str(other)
# --> 522 raise UnitConversionError(f"{unit_str} and {other_str} are not convertible")
#
# UnitConversionError: '1e-20 erg / (s cm2)' (energy flux/irradiance) and '' (dimensionless) are not convertible
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/ipywidgets/widgets/widget.py:191, in CallbackDispatcher.__call__(self, *args, **kwargs)
#     189 for callback in self.callbacks:
#     190     try:
# --> 191         local_value = callback(*args, **kwargs)
#     192     except Exception as e:
#     193         ip = get_ipython()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/ipympl/backend_nbagg.py:289, in Canvas._handle_message(self, object, content, buffers)
#     286     self.manager.handle_json(content)
#     288 else:
# --> 289     self.manager.handle_json(content)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:502, in FigureManagerWebAgg.handle_json(self, content)
#     501 def handle_json(self, content):
# --> 502     self.canvas.handle_event(content)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:289, in FigureCanvasWebAggCore.handle_event(self, event)
#     286 e_type = event['type']
#     287 handler = getattr(self, f'handle_{e_type}',
#     288                   self.handle_unknown_event)
# --> 289 return handler(event)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:336, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     331     MouseEvent('scroll_event', self, x, y, step=event['step'],
#     332                modifiers=modifiers, guiEvent=guiEvent)._process()
#     333 elif e_type == 'motion_notify':
#     334     MouseEvent(e_type + '_event', self, x, y,
#     335                buttons=buttons, modifiers=modifiers, guiEvent=guiEvent,
# --> 336                )._process()
#     337 elif e_type in ['figure_enter', 'figure_leave']:
#     338     LocationEvent(e_type + '_event', self, x, y,
#     339                   modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backend_bases.py:1202, in Event._process(self)
#    1200 def _process(self):
#    1201     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1202     self.canvas.callbacks.process(self.name, self)
#    1203     self.guiEvent = None
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/cbook.py:395, in CallbackRegistry.process(self, s, *args, **kwargs)
#     393 except Exception as exc:
#     394     if self.exception_handler is not None:
# --> 395         self.exception_handler(exc)
#     396     else:
#     397         raise
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/cbook.py:114, in _exception_printer(exc)
#     112 def _exception_printer(exc):
#     113     if _get_running_interactive_framework() in ["headless", None]:
# --> 114         raise exc
#     115     else:
#     116         traceback.print_exc()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/cbook.py:390, in CallbackRegistry.process(self, s, *args, **kwargs)
#     388 if func is not None:
#     389     try:
# --> 390         func(*args, **kwargs)
#     391     # this does not capture KeyboardInterrupt, SystemExit,
#     392     # and GeneratorExit
#     393     except Exception as exc:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backend_bases.py:3116, in NavigationToolbar2.mouse_move(self, event)
#    3114 def mouse_move(self, event):
#    3115     self._update_cursor(event)
# -> 3116     self.set_message(self._mouse_event_to_message(event))
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backend_bases.py:3108, in NavigationToolbar2._mouse_event_to_message(event)
#    3106 data = a.get_cursor_data(event)
#    3107 if data is not None:
# -> 3108     data_str = a.format_cursor_data(data).rstrip()
#    3109     if data_str:
#    3110         s = s + '\n' + data_str
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:1435, in Artist.format_cursor_data(self, data)
#    1414 """
#    1415 Return a string representation of *data*.
#    1416
#    (...)   1429 get_cursor_data
#    1430 """
#    1431 if np.ndim(data) == 0 and hasattr(self, "_format_cursor_data_override"):
#    1432     # workaround for ScalarMappable to be able to define its own
#    1433     # format_cursor_data(). See ScalarMappable._format_cursor_data_override
#    1434     # for details.
# -> 1435     return self._format_cursor_data_override(data)
#    1436 else:
#    1437     try:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colorizer.py:486, in _ColorizerInterface._format_cursor_data_override(self, data)
#     483     data = [data]
#     484     n_s = [self.cmap.N]
# --> 486 os = [f"{d:-#.{self._sig_digits_from_norm(no, d, n)}g}"
#     487       for no, d, n in zip(norms, data, n_s)]
#     488 return f"[{', '.join(os)}]"
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colorizer.py:495, in _ColorizerInterface._sig_digits_from_norm(norm, data, n)
#     490 @staticmethod
#     491 def _sig_digits_from_norm(norm, data, n):
#     492     # Determines the number of significant digits
#     493     # to use for a number given a norm, and n, where n is the
#     494     # number of colors in  the colormap.
# --> 495     normed = norm(data)
#     496     if np.isfinite(normed):
#     497         if isinstance(norm, colors.BoundaryNorm):
#     498             # not an invertible normalization mapping
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colors.py:2541, in Normalize.__call__(self, value, clip)
#    2538 if clip is None:
#    2539     clip = self.clip
# -> 2541 result, is_scalar = self.process_value(value)
#    2543 if self.vmin is None or self.vmax is None:
#    2544     self.autoscale_None(result)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colors.py:2525, in Normalize.process_value(value)
#    2523 if is_scalar:
#    2524     value = [value]
# -> 2525 dtype = np.min_scalar_type(value)
#    2526 if np.issubdtype(dtype, np.integer) or dtype.type is np.bool_:
#    2527     # bool_/int8/int16 -> float32; int32/int64 -> float64
#    2528     dtype = np.promote_types(dtype, np.float32)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:1348, in Quantity.__float__(self)
#    1346     return float(self.to_value(dimensionless_unscaled))
#    1347 except (UnitsError, TypeError):
# -> 1348     raise TypeError(
#    1349         "only dimensionless scalar quantities can be "
#    1350         "converted to Python scalars"
#    1351     )
#
# TypeError: only dimensionless scalar quantities can be converted to Python scalars
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:992, in Quantity.to_value(self, unit, equivalencies)
#     991 try:
# --> 992     scale = self.unit._to(unit)
#     993 except Exception:
#     994     # Short-cut failed; try default (maybe equivalencies help).
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:623, in UnitBase._to(self, other)
#     621         return self_decomposed.scale / other_decomposed.scale
# --> 623 raise UnitConversionError(f"'{self!r}' is not a scaled version of '{other!r}'")
#
# UnitConversionError: 'Unit("1e-20 erg / (s cm2)")' is not a scaled version of 'Unit(dimensionless)'
#
# During handling of the above exception, another exception occurred:
#
# UnitConversionError                       Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:1346, in Quantity.__float__(self)
#    1345 try:
# -> 1346     return float(self.to_value(dimensionless_unscaled))
#    1347 except (UnitsError, TypeError):
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:995, in Quantity.to_value(self, unit, equivalencies)
#     993 except Exception:
#     994     # Short-cut failed; try default (maybe equivalencies help).
# --> 995     value = self._to_value(unit, equivalencies)
#     996 else:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:901, in Quantity._to_value(self, unit, equivalencies)
#     899 if not self.dtype.names or isinstance(self.unit, StructuredUnit):
#     900     # Standard path, let unit to do work.
# --> 901     return self.unit.to(
#     902         unit, self.view(np.ndarray), equivalencies=equivalencies
#     903     )
#     905 else:
#     906     # The .to() method of a simple unit cannot convert a structured
#     907     # dtype, so we work around it, by recursing.
#     908     # TODO: deprecate this?
#     909     # Convert simple to Structured on initialization?
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:659, in UnitBase.to(self, other, value, equivalencies)
#     658 else:
# --> 659     return self.get_converter(Unit(other), equivalencies)(value)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:588, in UnitBase.get_converter(self, other, equivalencies)
#     586                 return lambda v: b(converter(v))
# --> 588 raise exc
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:571, in UnitBase.get_converter(self, other, equivalencies)
#     570 try:
# --> 571     return self._apply_equivalencies(
#     572         self, other, self._normalize_equivalencies(equivalencies)
#     573     )
#     574 except UnitsError as exc:
#     575     # Last hope: maybe other knows how to do it?
#     576     # We assume the equivalencies have the unit itself as first item.
#     577     # TODO: maybe better for other to have a `_back_converter` method?
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:522, in UnitBase._apply_equivalencies(self, unit, other, equivalencies)
#     520 other_str = get_err_str(other)
# --> 522 raise UnitConversionError(f"{unit_str} and {other_str} are not convertible")
#
# UnitConversionError: '1e-20 erg / (s cm2)' (energy flux/irradiance) and '' (dimensionless) are not convertible
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/ipywidgets/widgets/widget.py:191, in CallbackDispatcher.__call__(self, *args, **kwargs)
#     189 for callback in self.callbacks:
#     190     try:
# --> 191         local_value = callback(*args, **kwargs)
#     192     except Exception as e:
#     193         ip = get_ipython()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/ipympl/backend_nbagg.py:289, in Canvas._handle_message(self, object, content, buffers)
#     286     self.manager.handle_json(content)
#     288 else:
# --> 289     self.manager.handle_json(content)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:502, in FigureManagerWebAgg.handle_json(self, content)
#     501 def handle_json(self, content):
# --> 502     self.canvas.handle_event(content)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:289, in FigureCanvasWebAggCore.handle_event(self, event)
#     286 e_type = event['type']
#     287 handler = getattr(self, f'handle_{e_type}',
#     288                   self.handle_unknown_event)
# --> 289 return handler(event)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:336, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     331     MouseEvent('scroll_event', self, x, y, step=event['step'],
#     332                modifiers=modifiers, guiEvent=guiEvent)._process()
#     333 elif e_type == 'motion_notify':
#     334     MouseEvent(e_type + '_event', self, x, y,
#     335                buttons=buttons, modifiers=modifiers, guiEvent=guiEvent,
# --> 336                )._process()
#     337 elif e_type in ['figure_enter', 'figure_leave']:
#     338     LocationEvent(e_type + '_event', self, x, y,
#     339                   modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backend_bases.py:1202, in Event._process(self)
#    1200 def _process(self):
#    1201     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1202     self.canvas.callbacks.process(self.name, self)
#    1203     self.guiEvent = None
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/cbook.py:395, in CallbackRegistry.process(self, s, *args, **kwargs)
#     393 except Exception as exc:
#     394     if self.exception_handler is not None:
# --> 395         self.exception_handler(exc)
#     396     else:
#     397         raise
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/cbook.py:114, in _exception_printer(exc)
#     112 def _exception_printer(exc):
#     113     if _get_running_interactive_framework() in ["headless", None]:
# --> 114         raise exc
#     115     else:
#     116         traceback.print_exc()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/cbook.py:390, in CallbackRegistry.process(self, s, *args, **kwargs)
#     388 if func is not None:
#     389     try:
# --> 390         func(*args, **kwargs)
#     391     # this does not capture KeyboardInterrupt, SystemExit,
#     392     # and GeneratorExit
#     393     except Exception as exc:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backend_bases.py:3116, in NavigationToolbar2.mouse_move(self, event)
#    3114 def mouse_move(self, event):
#    3115     self._update_cursor(event)
# -> 3116     self.set_message(self._mouse_event_to_message(event))
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backend_bases.py:3108, in NavigationToolbar2._mouse_event_to_message(event)
#    3106 data = a.get_cursor_data(event)
#    3107 if data is not None:
# -> 3108     data_str = a.format_cursor_data(data).rstrip()
#    3109     if data_str:
#    3110         s = s + '\n' + data_str
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:1435, in Artist.format_cursor_data(self, data)
#    1414 """
#    1415 Return a string representation of *data*.
#    1416
#    (...)   1429 get_cursor_data
#    1430 """
#    1431 if np.ndim(data) == 0 and hasattr(self, "_format_cursor_data_override"):
#    1432     # workaround for ScalarMappable to be able to define its own
#    1433     # format_cursor_data(). See ScalarMappable._format_cursor_data_override
#    1434     # for details.
# -> 1435     return self._format_cursor_data_override(data)
#    1436 else:
#    1437     try:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colorizer.py:486, in _ColorizerInterface._format_cursor_data_override(self, data)
#     483     data = [data]
#     484     n_s = [self.cmap.N]
# --> 486 os = [f"{d:-#.{self._sig_digits_from_norm(no, d, n)}g}"
#     487       for no, d, n in zip(norms, data, n_s)]
#     488 return f"[{', '.join(os)}]"
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colorizer.py:495, in _ColorizerInterface._sig_digits_from_norm(norm, data, n)
#     490 @staticmethod
#     491 def _sig_digits_from_norm(norm, data, n):
#     492     # Determines the number of significant digits
#     493     # to use for a number given a norm, and n, where n is the
#     494     # number of colors in  the colormap.
# --> 495     normed = norm(data)
#     496     if np.isfinite(normed):
#     497         if isinstance(norm, colors.BoundaryNorm):
#     498             # not an invertible normalization mapping
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colors.py:2541, in Normalize.__call__(self, value, clip)
#    2538 if clip is None:
#    2539     clip = self.clip
# -> 2541 result, is_scalar = self.process_value(value)
#    2543 if self.vmin is None or self.vmax is None:
#    2544     self.autoscale_None(result)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colors.py:2525, in Normalize.process_value(value)
#    2523 if is_scalar:
#    2524     value = [value]
# -> 2525 dtype = np.min_scalar_type(value)
#    2526 if np.issubdtype(dtype, np.integer) or dtype.type is np.bool_:
#    2527     # bool_/int8/int16 -> float32; int32/int64 -> float64
#    2528     dtype = np.promote_types(dtype, np.float32)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:1348, in Quantity.__float__(self)
#    1346     return float(self.to_value(dimensionless_unscaled))
#    1347 except (UnitsError, TypeError):
# -> 1348     raise TypeError(
#    1349         "only dimensionless scalar quantities can be "
#    1350         "converted to Python scalars"
#    1351     )
#
# TypeError: only dimensionless scalar quantities can be converted to Python scalars
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:992, in Quantity.to_value(self, unit, equivalencies)
#     991 try:
# --> 992     scale = self.unit._to(unit)
#     993 except Exception:
#     994     # Short-cut failed; try default (maybe equivalencies help).
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:623, in UnitBase._to(self, other)
#     621         return self_decomposed.scale / other_decomposed.scale
# --> 623 raise UnitConversionError(f"'{self!r}' is not a scaled version of '{other!r}'")
#
# UnitConversionError: 'Unit("1e-20 erg / (s cm2)")' is not a scaled version of 'Unit(dimensionless)'
#
# During handling of the above exception, another exception occurred:
#
# UnitConversionError                       Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:1346, in Quantity.__float__(self)
#    1345 try:
# -> 1346     return float(self.to_value(dimensionless_unscaled))
#    1347 except (UnitsError, TypeError):
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:995, in Quantity.to_value(self, unit, equivalencies)
#     993 except Exception:
#     994     # Short-cut failed; try default (maybe equivalencies help).
# --> 995     value = self._to_value(unit, equivalencies)
#     996 else:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:901, in Quantity._to_value(self, unit, equivalencies)
#     899 if not self.dtype.names or isinstance(self.unit, StructuredUnit):
#     900     # Standard path, let unit to do work.
# --> 901     return self.unit.to(
#     902         unit, self.view(np.ndarray), equivalencies=equivalencies
#     903     )
#     905 else:
#     906     # The .to() method of a simple unit cannot convert a structured
#     907     # dtype, so we work around it, by recursing.
#     908     # TODO: deprecate this?
#     909     # Convert simple to Structured on initialization?
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:659, in UnitBase.to(self, other, value, equivalencies)
#     658 else:
# --> 659     return self.get_converter(Unit(other), equivalencies)(value)
#
# ...
#     501 def handle_json(self, content):
# --> 502     self.canvas.handle_event(content)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:289, in FigureCanvasWebAggCore.handle_event(self, event)
#     286 e_type = event['type']
#     287 handler = getattr(self, f'handle_{e_type}',
#     288                   self.handle_unknown_event)
# --> 289 return handler(event)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:336, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     331     MouseEvent('scroll_event', self, x, y, step=event['step'],
#     332                modifiers=modifiers, guiEvent=guiEvent)._process()
#     333 elif e_type == 'motion_notify':
#     334     MouseEvent(e_type + '_event', self, x, y,
#     335                buttons=buttons, modifiers=modifiers, guiEvent=guiEvent,
# --> 336                )._process()
#     337 elif e_type in ['figure_enter', 'figure_leave']:
#     338     LocationEvent(e_type + '_event', self, x, y,
#     339                   modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backend_bases.py:1202, in Event._process(self)
#    1200 def _process(self):
#    1201     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1202     self.canvas.callbacks.process(self.name, self)
#    1203     self.guiEvent = None
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/cbook.py:395, in CallbackRegistry.process(self, s, *args, **kwargs)
#     393 except Exception as exc:
#     394     if self.exception_handler is not None:
# --> 395         self.exception_handler(exc)
#     396     else:
#     397         raise
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/cbook.py:114, in _exception_printer(exc)
#     112 def _exception_printer(exc):
#     113     if _get_running_interactive_framework() in ["headless", None]:
# --> 114         raise exc
#     115     else:
#     116         traceback.print_exc()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/cbook.py:390, in CallbackRegistry.process(self, s, *args, **kwargs)
#     388 if func is not None:
#     389     try:
# --> 390         func(*args, **kwargs)
#     391     # this does not capture KeyboardInterrupt, SystemExit,
#     392     # and GeneratorExit
#     393     except Exception as exc:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backend_bases.py:3116, in NavigationToolbar2.mouse_move(self, event)
#    3114 def mouse_move(self, event):
#    3115     self._update_cursor(event)
# -> 3116     self.set_message(self._mouse_event_to_message(event))
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backend_bases.py:3108, in NavigationToolbar2._mouse_event_to_message(event)
#    3106 data = a.get_cursor_data(event)
#    3107 if data is not None:
# -> 3108     data_str = a.format_cursor_data(data).rstrip()
#    3109     if data_str:
#    3110         s = s + '\n' + data_str
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:1435, in Artist.format_cursor_data(self, data)
#    1414 """
#    1415 Return a string representation of *data*.
#    1416
#    (...)   1429 get_cursor_data
#    1430 """
#    1431 if np.ndim(data) == 0 and hasattr(self, "_format_cursor_data_override"):
#    1432     # workaround for ScalarMappable to be able to define its own
#    1433     # format_cursor_data(). See ScalarMappable._format_cursor_data_override
#    1434     # for details.
# -> 1435     return self._format_cursor_data_override(data)
#    1436 else:
#    1437     try:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colorizer.py:486, in _ColorizerInterface._format_cursor_data_override(self, data)
#     483     data = [data]
#     484     n_s = [self.cmap.N]
# --> 486 os = [f"{d:-#.{self._sig_digits_from_norm(no, d, n)}g}"
#     487       for no, d, n in zip(norms, data, n_s)]
#     488 return f"[{', '.join(os)}]"
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colorizer.py:495, in _ColorizerInterface._sig_digits_from_norm(norm, data, n)
#     490 @staticmethod
#     491 def _sig_digits_from_norm(norm, data, n):
#     492     # Determines the number of significant digits
#     493     # to use for a number given a norm, and n, where n is the
#     494     # number of colors in  the colormap.
# --> 495     normed = norm(data)
#     496     if np.isfinite(normed):
#     497         if isinstance(norm, colors.BoundaryNorm):
#     498             # not an invertible normalization mapping
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colors.py:2541, in Normalize.__call__(self, value, clip)
#    2538 if clip is None:
#    2539     clip = self.clip
# -> 2541 result, is_scalar = self.process_value(value)
#    2543 if self.vmin is None or self.vmax is None:
#    2544     self.autoscale_None(result)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colors.py:2525, in Normalize.process_value(value)
#    2523 if is_scalar:
#    2524     value = [value]
# -> 2525 dtype = np.min_scalar_type(value)
#    2526 if np.issubdtype(dtype, np.integer) or dtype.type is np.bool_:
#    2527     # bool_/int8/int16 -> float32; int32/int64 -> float64
#    2528     dtype = np.promote_types(dtype, np.float32)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:1348, in Quantity.__float__(self)
#    1346     return float(self.to_value(dimensionless_unscaled))
#    1347 except (UnitsError, TypeError):
# -> 1348     raise TypeError(
#    1349         "only dimensionless scalar quantities can be "
#    1350         "converted to Python scalars"
#    1351     )
#
# TypeError: only dimensionless scalar quantities can be converted to Python scalars
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:992, in Quantity.to_value(self, unit, equivalencies)
#     991 try:
# --> 992     scale = self.unit._to(unit)
#     993 except Exception:
#     994     # Short-cut failed; try default (maybe equivalencies help).
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:623, in UnitBase._to(self, other)
#     621         return self_decomposed.scale / other_decomposed.scale
# --> 623 raise UnitConversionError(f"'{self!r}' is not a scaled version of '{other!r}'")
#
# UnitConversionError: 'Unit("1e-20 erg / (s cm2)")' is not a scaled version of 'Unit(dimensionless)'
#
# During handling of the above exception, another exception occurred:
#
# UnitConversionError                       Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:1346, in Quantity.__float__(self)
#    1345 try:
# -> 1346     return float(self.to_value(dimensionless_unscaled))
#    1347 except (UnitsError, TypeError):
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:995, in Quantity.to_value(self, unit, equivalencies)
#     993 except Exception:
#     994     # Short-cut failed; try default (maybe equivalencies help).
# --> 995     value = self._to_value(unit, equivalencies)
#     996 else:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:901, in Quantity._to_value(self, unit, equivalencies)
#     899 if not self.dtype.names or isinstance(self.unit, StructuredUnit):
#     900     # Standard path, let unit to do work.
# --> 901     return self.unit.to(
#     902         unit, self.view(np.ndarray), equivalencies=equivalencies
#     903     )
#     905 else:
#     906     # The .to() method of a simple unit cannot convert a structured
#     907     # dtype, so we work around it, by recursing.
#     908     # TODO: deprecate this?
#     909     # Convert simple to Structured on initialization?
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:659, in UnitBase.to(self, other, value, equivalencies)
#     658 else:
# --> 659     return self.get_converter(Unit(other), equivalencies)(value)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:588, in UnitBase.get_converter(self, other, equivalencies)
#     586                 return lambda v: b(converter(v))
# --> 588 raise exc
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:571, in UnitBase.get_converter(self, other, equivalencies)
#     570 try:
# --> 571     return self._apply_equivalencies(
#     572         self, other, self._normalize_equivalencies(equivalencies)
#     573     )
#     574 except UnitsError as exc:
#     575     # Last hope: maybe other knows how to do it?
#     576     # We assume the equivalencies have the unit itself as first item.
#     577     # TODO: maybe better for other to have a `_back_converter` method?
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/core.py:522, in UnitBase._apply_equivalencies(self, unit, other, equivalencies)
#     520 other_str = get_err_str(other)
# --> 522 raise UnitConversionError(f"{unit_str} and {other_str} are not convertible")
#
# UnitConversionError: '1e-20 erg / (s cm2)' (energy flux/irradiance) and '' (dimensionless) are not convertible
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/ipywidgets/widgets/widget.py:191, in CallbackDispatcher.__call__(self, *args, **kwargs)
#     189 for callback in self.callbacks:
#     190     try:
# --> 191         local_value = callback(*args, **kwargs)
#     192     except Exception as e:
#     193         ip = get_ipython()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/ipympl/backend_nbagg.py:289, in Canvas._handle_message(self, object, content, buffers)
#     286     self.manager.handle_json(content)
#     288 else:
# --> 289     self.manager.handle_json(content)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:502, in FigureManagerWebAgg.handle_json(self, content)
#     501 def handle_json(self, content):
# --> 502     self.canvas.handle_event(content)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:289, in FigureCanvasWebAggCore.handle_event(self, event)
#     286 e_type = event['type']
#     287 handler = getattr(self, f'handle_{e_type}',
#     288                   self.handle_unknown_event)
# --> 289 return handler(event)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backends/backend_webagg_core.py:336, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     331     MouseEvent('scroll_event', self, x, y, step=event['step'],
#     332                modifiers=modifiers, guiEvent=guiEvent)._process()
#     333 elif e_type == 'motion_notify':
#     334     MouseEvent(e_type + '_event', self, x, y,
#     335                buttons=buttons, modifiers=modifiers, guiEvent=guiEvent,
# --> 336                )._process()
#     337 elif e_type in ['figure_enter', 'figure_leave']:
#     338     LocationEvent(e_type + '_event', self, x, y,
#     339                   modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backend_bases.py:1202, in Event._process(self)
#    1200 def _process(self):
#    1201     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1202     self.canvas.callbacks.process(self.name, self)
#    1203     self.guiEvent = None
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/cbook.py:395, in CallbackRegistry.process(self, s, *args, **kwargs)
#     393 except Exception as exc:
#     394     if self.exception_handler is not None:
# --> 395         self.exception_handler(exc)
#     396     else:
#     397         raise
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/cbook.py:114, in _exception_printer(exc)
#     112 def _exception_printer(exc):
#     113     if _get_running_interactive_framework() in ["headless", None]:
# --> 114         raise exc
#     115     else:
#     116         traceback.print_exc()
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/cbook.py:390, in CallbackRegistry.process(self, s, *args, **kwargs)
#     388 if func is not None:
#     389     try:
# --> 390         func(*args, **kwargs)
#     391     # this does not capture KeyboardInterrupt, SystemExit,
#     392     # and GeneratorExit
#     393     except Exception as exc:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backend_bases.py:3116, in NavigationToolbar2.mouse_move(self, event)
#    3114 def mouse_move(self, event):
#    3115     self._update_cursor(event)
# -> 3116     self.set_message(self._mouse_event_to_message(event))
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/backend_bases.py:3108, in NavigationToolbar2._mouse_event_to_message(event)
#    3106 data = a.get_cursor_data(event)
#    3107 if data is not None:
# -> 3108     data_str = a.format_cursor_data(data).rstrip()
#    3109     if data_str:
#    3110         s = s + '\n' + data_str
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/artist.py:1435, in Artist.format_cursor_data(self, data)
#    1414 """
#    1415 Return a string representation of *data*.
#    1416
#    (...)   1429 get_cursor_data
#    1430 """
#    1431 if np.ndim(data) == 0 and hasattr(self, "_format_cursor_data_override"):
#    1432     # workaround for ScalarMappable to be able to define its own
#    1433     # format_cursor_data(). See ScalarMappable._format_cursor_data_override
#    1434     # for details.
# -> 1435     return self._format_cursor_data_override(data)
#    1436 else:
#    1437     try:
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colorizer.py:486, in _ColorizerInterface._format_cursor_data_override(self, data)
#     483     data = [data]
#     484     n_s = [self.cmap.N]
# --> 486 os = [f"{d:-#.{self._sig_digits_from_norm(no, d, n)}g}"
#     487       for no, d, n in zip(norms, data, n_s)]
#     488 return f"[{', '.join(os)}]"
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colorizer.py:495, in _ColorizerInterface._sig_digits_from_norm(norm, data, n)
#     490 @staticmethod
#     491 def _sig_digits_from_norm(norm, data, n):
#     492     # Determines the number of significant digits
#     493     # to use for a number given a norm, and n, where n is the
#     494     # number of colors in  the colormap.
# --> 495     normed = norm(data)
#     496     if np.isfinite(normed):
#     497         if isinstance(norm, colors.BoundaryNorm):
#     498             # not an invertible normalization mapping
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colors.py:2541, in Normalize.__call__(self, value, clip)
#    2538 if clip is None:
#    2539     clip = self.clip
# -> 2541 result, is_scalar = self.process_value(value)
#    2543 if self.vmin is None or self.vmax is None:
#    2544     self.autoscale_None(result)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/matplotlib/colors.py:2525, in Normalize.process_value(value)
#    2523 if is_scalar:
#    2524     value = [value]
# -> 2525 dtype = np.min_scalar_type(value)
#    2526 if np.issubdtype(dtype, np.integer) or dtype.type is np.bool_:
#    2527     # bool_/int8/int16 -> float32; int32/int64 -> float64
#    2528     dtype = np.promote_types(dtype, np.float32)
#
# File ~/miniconda3/envs/nitro/lib/python3.14/site-packages/astropy/units/quantity.py:1348, in Quantity.__float__(self)
#    1346     return float(self.to_value(dimensionless_unscaled))
#    1347 except (UnitsError, TypeError):
# -> 1348     raise TypeError(
#    1349         "only dimensionless scalar quantities can be "
#    1350         "converted to Python scalars"
#    1351     )
#
# TypeError: only dimensionless scalar quantities can be converted to Python scalars

# %% [markdown]
# ## Calculate Seeing

# %% [markdown]
# Obtain the pixel scale in arcseconds

# %%
pixel_scales = proj_plane_pixel_scales(cube.wcs.celestial) * u.deg

scale_y, scale_x = pixel_scales.to(u.arcsec)

print(f"Pixel scale along X: {scale_x}")
print(f"Pixel scale along Y: {scale_y}")
# Out:
# Pixel scale along X: 0.025419999999999995 arcsec
# Pixel scale along Y: 0.025189999999999994 arcsec

# %% [markdown]
# Define a circular aperture at the zone of peak emission of the galaxy.

# %%
# Define the center position
center_pos = [177, 197]

# Define the circular mask with radius of 0.15 arcseconds
yy, xx = np.indices(center_pos, dtype='float')
radius = ((yy-2)**2 + (xx-2)**2)**0.5
mask = radius <= 2

# %% [markdown]
# Plot the spectrum in the point

# %%
z = 0.0054

point_spectrum = cube[:, center_pos[1], center_pos[0]]

axis_unit = cube.spectral_axis.unit

x_obs = cube.spectral_axis
x_rest = x_obs / (1 + z)

fig, ax = plt.subplots(figsize=(16, 6))

ax.plot(x_rest.value, point_spectrum.value)


ax.set_xlabel(f"Spectral Axis [{axis_unit}]")
ax.set_ylabel(f"Intensity [{cube.unit}]")
ax.set_title("Spectrum at a given Pixel")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Fit lines to spectrum

# %% [markdown]
# We will use either a Gaussian1D profile or a Moffat1D profile
